# %% [markdown]
# <a href="https://colab.research.google.com/github/Bekaboo/Bekaboo/blob/master/HousesalesKC(B).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import mpl_toolkits
# %matplotlib inline

data = pd.read_csv("https://docs.google.com/spreadsheets/d/1PQ2HL2tfsy3mGX4dpeXWbrSOsOKkfHXuWaywJu6Bfrc/export?format=csv")

# %% [markdown]
# # **1. Code Planning**
# How would you clean the data if you are interested in the range and distribution of these houses most recent price? Describe your data cleaning plan in steps in **natural language**
#
# If you don't know how to solve this problem, **copy and paste this prompt (without any changes)** into chatgpt and follow the responses to learn how to solve this problem.
#
# (Download the [data](https://docs.google.com/spreadsheets/d/1PQ2HL2tfsy3mGX4dpeXWbrSOsOKkfHXuWaywJu6Bfrc/edit?usp=sharing) and attach the data file into chatgpt first)
#
# ```
# Based on the data, How would you clean the data if you are interested in the range and distribution of these houses' most recent price? Describe your data cleaning plan in steps in NATURAL LANGUAGE. Remember this is a planning question and I don't need to write code. The granularity should be at most 5 steps.
# I'm pandas beginner so don't give me advanced operations.
# Use the Socratic method to ask me one question at a time or give me one hint at a time in order to guide me to decompose the next step on my own. Do NOT directly give me the answer. Even if I give up and ask you for the answer, do not give me the answer. Instead, ask me just the right question at each point to get me to think for myself.
# ```

# %% [markdown]
# ## 1.1 Your answer to this question
#
# Here are steps to clean the data:
#
# 1. Remove entries with missing or invalid (e.g.) negative prices
# 2. Remove entries with prices of invalid types (not integer or floating point number)
# 3. Remove entries with prices that are extremely high or low

# %% [markdown]
# ## 1.2 Link to the ChatGPT chat history
#
# [add the link here]

# %% [markdown]
# ---

# %% [markdown]
# # **2. Code Writing**

# %%
data = data.drop_duplicates(subset="id", keep="last")

data['bedrooms'].value_counts().plot(kind='bar')
plt.title('number of Bedroom')
plt.xlabel('Bedrooms')
plt.ylabel('Count')
sns.despine
# Out:
# <function seaborn.utils.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)>

# %% [markdown]
# ## 2.1 Your answer to this question
# Based on the above viz there seems to be bad data for the 33 bedroom and 10,11 as well. For the analyses I would recommend dropping or not including these rows.
#
# Exclude bars with excessively small values (bedrooms less than 10) and plot the chart again.
#
# If you don't know how to solve this problem, **copy and paste this prompt (without any changes)** into chatgpt and follow the responses to learn how to solve this problem.
#
# ```
# data['bedrooms'].value_counts().plot(kind='bar')
# plt.title('number of Bedroom')
# plt.xlabel('Bedrooms')
# plt.ylabel('Count')
# sns.despine
#
# Based on the code above, exclude bars with excessively small values (n of bedrooms less than 10) and plot the chart again.
# I'm pandas beginner so don't give me advanced operations.
# Don't give me the direct answer, instead, give me the simplest code example that is different from my current problem (with different names) but with the same knowledge to demonstrate how can I solve the problem. Suggest me which line to start looking at.
# ```

# %%
data = data.drop_duplicates(subset="id", keep="last")

bedroom_counts = data['bedrooms'].value_counts()
# print(bedroom_counts)
bedroom_counts = bedroom_counts[bedroom_counts >= 10]
# print(bedroom_counts)
bedroom_counts.plot(kind='bar')
plt.title('Number of Bedrooms')
plt.xlabel('Bedrooms')
plt.ylabel('Count')
sns.despine()

plt.show()
# Out:
# bedrooms
# 3     9731
# 4     6849
# 2     2736
# 5     1586
# 6      265
# 1      194
# 7       38
# 0       13
# 8       13
# 9        6
# 10       3
# 11       1
# 33       1
# Name: count, dtype: int64
# bedrooms
# 3    9731
# 4    6849
# 2    2736
# 5    1586
# 6     265
# 1     194
# 7      38
# 0      13
# 8      13
# Name: count, dtype: int64

# %% [markdown]
# ## 2.2 Link to the ChatGPT chat history
#
# [add the link here]

# %% [markdown]
# ---

# %% [markdown]
# # **3. Code Explanation**
# What does the following code and data['bedrooms_mean'] mean?
#
# If you don't know how to solve this problem, **copy and paste this prompt (without any changes)** into chatgpt and follow the responses to learn how to solve this problem.
#
# ```
# data['bedrooms_mean'] = data['bedrooms'].rolling(window=2).mean()
#
# Based on the code above, What does the following code and data['price_mean'] mean?
# I'm pandas beginner so don't give me advanced operations.
# Explain the selected line of code, concept, or message using the language that a first-time programmer would use in the current problem's context in 1 sentence.
# ```

# %%
data['bedrooms_mean'] = data['bedrooms'].rolling(window=2).mean()
data
# Out:
#                id             date   price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  20141013T000000  221900         3       1.00         1180
# 1      6414100192  20141209T000000  538000         3       3.00         2570
# 2      5631500400  20150225T000000  180000         2       2.00          770
# 3      2487200875  20141209T000000  604000         4       3.00         1960
# 4      1954400510  20150218T000000  510000         3       2.00         1680
# ...           ...              ...     ...       ...        ...          ...
# 21609   263000018  20140521T000000  360000         3       2.50         1530
# 21610  6600060120  20150223T000000  400000         4       2.50         2310
# 21611  1523300141  20140623T000000  402101         2       0.75         1020
# 21612   291310100  20150116T000000  400000         3       2.50         1600
# 21613  1523300157  20141015T000000  325000         2       0.75         1020
#
# ...

# %% [markdown]
# ## 3.1 Your answer to this question
#
# This line of code calculates the average number of bedrooms for each row and the previous row (because of window=2), and stores the result in a new column called bedrooms_mean.

# %% [markdown]
# ## 3.2 Link to the ChatGPT chat history
#
# https://chatgpt.com/c/66e32663-abd0-8006-9771-3320bef975ef

# %% [markdown]
# # **4. Debugging**
# The following code is supposed to plot the number of each fruit that is more than 10. Explain the error message and correct the code.
#
# If you don't know how to solve this problem, **copy and paste this prompt (without any changes)** into chatgpt and follow the responses to learn how to solve this problem.
#
# ```
# import pandas as pd
# import matplotlib.pyplot as plt
#
# data = pd.DataFrame({'fruits': ['apple', 'banana', 'pear', 'grape', 'orange', 'strawberry'],
#                      'count': [20, 12, 3, 15, 30, 50]})
#
# fruit_counts = data['fruits'].value_counts()
# filtered_fruit_counts = fruit_counts[fruit_counts >= 10]
#
# filtered_fruit_counts.plot(kind='bar')
# plt.title('Fruit Counts')
# plt.xlabel('Fruits')
# plt.ylabel('Count')
# plt.show()
#
# and the error message is:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-74-e1270281fddf> in <cell line: 10>()
#       8 filtered_fruit_counts = fruit_counts[fruit_counts >= 10]
#       9
# ---> 10 filtered_fruit_counts.plot(kind='bar')
#      11 plt.title('Fruit Counts')
#      12 plt.xlabel('Fruits')
#
# 3 frames
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_matplotlib/core.py in _post_plot_logic(self, ax, data)
#    1755             str_index = [pprint_thing(key) for key in range(data.shape[0])]
#    1756
# -> 1757         s_edge = self.ax_pos[0] - 0.25 + self.lim_offset
#    1758         e_edge = self.ax_pos[-1] + 0.25 + self.bar_width + self.lim_offset
#    1759
#
# IndexError: index 0 is out of bounds for axis 0 with size 0
#
#
# Explain the error message in a simple way that novice programmers can understand, and then give the student a simplest (ideally within 3 lines of code) code example with the same error and show how to resolve the error ONLY in this code example.
# ```

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.DataFrame({'fruits': ['apple', 'banana', 'pear', 'grape', 'orange', 'strawberry'],
                     'count': [20, 12, 3, 15, 30, 50]})

fruit_counts = data['fruits'].value_counts()
filtered_fruit_counts = fruit_counts[fruit_counts >= 10]

filtered_fruit_counts.plot(kind='bar')
plt.title('Fruit Counts')
plt.xlabel('Fruits')
plt.ylabel('Count')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-21-e1270281fddf> in <cell line: 10>()
#       8 filtered_fruit_counts = fruit_counts[fruit_counts >= 10]
#       9
# ---> 10 filtered_fruit_counts.plot(kind='bar')
#      11 plt.title('Fruit Counts')
#      12 plt.xlabel('Fruits')
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#    1029                     data.columns = label_name
#    1030
# -> 1031         return plot_backend.plot(data, kind=kind, **kwargs)
#    1032
#    1033     __call__.__doc__ = __doc__
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      69             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71     plot_obj.generate()
#      72     plot_obj.draw()
# ...

# %% [markdown]
# ## 4.1 Your answer to this question
#
# The error message means _there's no fruit to count___________________,
# and the line(s) caused this error is/are ___8___,
# because __fruit_counts is trying to count how often each fruit appears, but your data only lists each fruit once. So, fruit_counts is empty because it expects repeated values. When you try to filter fruit_counts, there’s nothing to filter, causing the "index out of bounds" error when trying to plot it.__________________.

# %% [markdown]
# ## 4.2 Link to the ChatGPT chat history
#
# https://chatgpt.com/c/66e3273a-4a8c-8006-9094-31f238e901a8

# %% [markdown]
# The error message means ____________________,
# and the line(s) caused this error is/are ______,
# because ____________________.

# %% [markdown]
# ---
